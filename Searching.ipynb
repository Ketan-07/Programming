# %% [markdown]
# # Linear Search
#
# ## Time Complexity :-
# * Best Case - O(1)
# * Worst Case - O(N)

# %%
li=[10,2,5,8,3,4]
key=int(input("n:"))
bool=False
for i in range(len(li)):
    if key==li[i]:
        print(f"{key} is found at the index {i} and position {i+1}")
        bool=True       
        break
if not bool:
    print("Key not found in the list")
# Out:
# Key not found in the list

# %% [markdown]
# # Linear Search using - For-Else
# * we can use else and for under same indentation when for loop dosen't executes full and break in middle and we need to print some extra messages or do some activity

# %%
li=[10,2,5,8,3,4]
key=int(input("n:"))
for i in range(len(li)):
    if key==li[i]:
        print(f"{key} is found at the index {i} and position {i+1}")    
        break
else:
    print("Key not found in the list")
# Out:
# 3 is found at the index 4 and position 5

# %% [markdown]
# # Binary Search
