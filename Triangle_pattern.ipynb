# %% [markdown]
# # Day 4

# %%
n=int(input("Enter the value of n"))
for i in range(n):
    for j in range(n):
        if(i>j or i==j):
            print("*",end=" ")
        else:
            print(" ",end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *

# %%
n=int(input("Enter the value of n"))
for i in range(n):
    for j in range(0,i+1,1):
        # if(i>j or i==j):
        print("*",end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * * * *
# * * * * * * * *
# * * * * * * * * *
# * * * * * * * * * *

# %%
n=int(input("Enter the value of n"))
for i in range(n):
    for j in range(n):
        if(i<=j):
            print("*",end=" ")
        else:
            print(" ",end=" ")
    print()
# Out:
# * * * * *
#   * * * *
#     * * *
#       * *
#         *

# %% [markdown]
# # icube_coding

# %%
n=int(input("Enter the value of n"))
for i in range(n):
    for j in range(n):
        if(i+j<=n-1):
            print("*",end=" ")
        else:
            print(" ",end=" ")
    print()
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
n=int(input("Enter the value of n"))
for i in range(n):
    for j in range(n):
        if(i+j>=n-1):
            print("*",end=" ")
        else:
            print(" ",end=" ")
    print()
# Out:
#         *
#       * *
#     * * *
#   * * * *
# * * * * *

# %%
n=int(input("Enter the value of n"))
for i in range(n):
    for j in range(n):
        if(i+j==n-1):
            print("*",end=" ")
        else:
            print(" ",end=" ")
    print()
# Out:
#         *
#       *
#     *
#   *
# *

# %%
val=ord("A")
n=int(input("Enter the value of n"))
for i in range(n): 
    for j in range(n):
        if(i+j==n-1):
            print(chr(val),end=" ")
            val+=1
        else:
            print(" ",end=" ")
    print()
# Out:
#         A
#       B
#     C
#   D
# E
