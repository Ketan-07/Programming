# %%
a=10,20,30
# By default pyhton packs all the values into a as tuple
print(a)
print((type(a)))
# Above is example of packing
# Out:
# (10, 20, 30)
# <class 'tuple'>

# %%
l1=[1,2,3,4,5,6]
a,b,c,d,e,f=l1
print(a)
# unpacking by giving equal no of variables for the no of elements present in the collection
# Out:
# 1

# %%
l1=[1,2,3,4,5,6]
*a,b,c=l1
print(a)
print(b)
print(c)
# here assinging of values take place from last
# then the remaining will assigned to the elements with '*'
# Out:
# [1, 2, 3, 4]
# 5
# 6

# %%
s1='abcdef'
print(*s1)
l=[1,2,3,4,5,6]
print(*l)
# Out:
# a b c d e f
# 1 2 3 4 5 6
